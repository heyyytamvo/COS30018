# %% [markdown]
# # Importing Dependencies

# %%
# Task B2
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import os

# Task B3
import plotly.graph_objects as go
import plotly.express as px

# Task B4
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,SimpleRNN,LSTM, GRU, Dense, Dropout
import matplotlib.pyplot as plt
import sys

# Task B5
from tensorflow.keras import metrics

# Task B7
import tensorflow as tf

# %% [markdown]
# # Hyperparameters

# %%
# Task B2
TICKER = "AAPL"
START_DATE = "2010-01-01"
END_DATE = "2022-12-31"
LOOK_UP_DAYS = 20      
TRAINING_RATIO = 0.8    # 0.7 == 70%
SCALE_DATA = True
SCALING_METHOD = "MinMax"       # MinMax, Standard

# Task B3
TRADING_PERIOD = 60
CONSECUTIVE_DAYS = 300

# Task B4
NUMBER_OF_LAYER = 3
NUMBER_OF_HIDDEN_UNITS = 80
MODEL_NAME = "RNN"      ## "RNN". "LSTM", "GRU"
DROP_OUT_RATE = 0     ## dropout rate in [0,1]
NUMBER_OF_EPOCHS = 30
BATCH_SIZE = 32
FEATURE_PREDICT = "Close"    ## "Open", "High", "Close", "Low" 
LOSS_FUNCTION = "huber_loss" ## "mean_squared_error", "mean_absolute_error", "huber_loss"
OPTIMIZER = "adam"  ## "adam", "RMSprop", "SGD"

# Task B5
K_SEQUENCE = 20
START_TEST_DATE = "2024-01-01"
END_TEST_DATE = "2024-03-31"

# %% [markdown]
# # Task B2: DATA PROCESSING 1

# %% [markdown]
# ## Scaling dataset

# %%
def DataScaler(stock_data, scaling_method=SCALING_METHOD):

    DatasetScaler = None
    ColumnScalers = {

    }
    if scaling_method == "MinMax":
        DatasetScaler = preprocessing.MinMaxScaler()
        
    
    elif scaling_method == "Standard":
        DatasetScaler = preprocessing.StandardScaler()

    
    # Learn the whole dataset
    col_names = stock_data.columns
    features = stock_data[col_names]
    DatasetScaler.fit(features.values)
    features = DatasetScaler.transform(features.values)
    scaledDataFrame = pd.DataFrame(features, columns = col_names)
    scaledDataFrame.index = stock_data.index
    
    for column in col_names:
        column_scaler = None
        if scaling_method == "MinMax":
            column_scaler = preprocessing.MinMaxScaler()
        elif scaling_method == "Standard":
            column_scaler = preprocessing.StandardScaler()
        column_scaler.fit(stock_data[column].values.reshape(-1,1))
        ColumnScalers[column] = column_scaler

    return scaledDataFrame, DatasetScaler, ColumnScalers

# %% [markdown]
# ## Loading Data Function

# %%
def DataLoader(ticker=TICKER, start_date=START_DATE, end_date=END_DATE, scale=SCALE_DATA, scaling_method=SCALING_METHOD):
    '''
    ticker: is the code of the target ticker
    start_date: a start date string with format YYYY/MM/DD
    end_date: an end date string with format YYYY/MM/DD
    scale: a boolean value, True by default
    scaling_method: MinMax(by default), Standard.
    '''

    # result
    result = {
        "dataset": None,
        "datasetScaler": None,
        "columnScalers": None
    }

    # processing the input parameters
    start_date = dt.datetime.strptime(start_date, "%Y-%m-%d")
    end_date = dt.datetime.strptime(end_date, "%Y-%m-%d")


    # creating necessary folder
    if not os.path.isdir("results"):
        os.mkdir("results")
    
    if not os.path.isdir("data"):
        os.mkdir("data")


    
    # checking if the data is already downloaded 
    ## Get a list of files in the directory
    files = os.listdir("data")
    ## Check each file in the directory
    data = None
    for file_name in files:
        ## if we already downloaded the ticket data
        if file_name.startswith(ticker) and file_name.endswith(".csv"):
            ### Read the file 
            file_path = os.path.join("data", f"{ticker}.csv")
            data = pd.read_csv(file_path, parse_dates=['Date'])
            break

    ## else, we gonna download the stock data
    if data is None:
        stock_data = yf.download(ticker, start_date, end_date)
        file_path = os.path.join("data", f"{ticker}.csv")
        stock_data.to_csv(file_path)
        data = pd.read_csv(file_path, parse_dates=['Date'])

    # if the given time is included in the file, we just take the nessecary dataframe
    if data.head(1)["Date"].values[0] <= np.datetime64(start_date) and data.tail(1)["Date"].values[0] >= np.datetime64(end_date):
        data = data[(data['Date'] >= pd.to_datetime(start_date)) & (data['Date'] <= pd.to_datetime(end_date))]
        print("Local Stock Data is enough for requirements, do not need to download")
    else: 
        stock_data = yf.download(ticker, start_date, end_date)
        file_path = os.path.join("data", f"{ticker}.csv")
        stock_data.to_csv(file_path)
        data = pd.read_csv(file_path, parse_dates=['Date'])
        print("Local Stock Data is not enough for requirements, continuing downloading...")

    # Setting Date as Index
    data.set_index('Date', inplace=True)

    # Scale Data
    if scale:
        data, scaler, column_scalers = DataScaler(data, scaling_method)
        result["dataset"] = data
        result["datasetScaler"] = scaler
        result["columnScalers"] = column_scalers
        return result

    result["dataset"] = data
    
    return result

# %% [markdown]
# ## Splitting Dataset

# %%
def datasetSplitter(dataset: pd.DataFrame, look_up_days=LOOK_UP_DAYS, 
        training_ratio=TRAINING_RATIO,  
        feature_columns=['Open','High','Low','Close','Adj Close','Volume'], k_sequence=K_SEQUENCE):
    '''
    dataset: a Pandas Dataframe
    training_ratio: is equal to TRAINING_RATION constant
    '''
    # result
    splitResult = {
        "X_training_set": None,
        "Y_training_set": None,
    }

    x_data = []
    y_data = []
    total_records = len(dataset)
    for day in range(look_up_days, total_records - k_sequence):
        data_points = []
        y_data.append(dataset[FEATURE_PREDICT][day:day+k_sequence])

        for j in range(day - look_up_days, day):
            input_feature_x = []
        
            for column in feature_columns:
                if column == FEATURE_PREDICT:
                    continue
                input_feature_x.append(dataset[column].values.reshape(-1, 1)[j, 0])

            data_points.append(input_feature_x)
        x_data.append(data_points)
    splitResult["X_training_set"], splitResult["Y_training_set"] = x_data, y_data
    
    splitResult["X_training_set"] = np.array(splitResult["X_training_set"])
    splitResult["Y_training_set"] = np.array(splitResult["Y_training_set"])
    
    
    return splitResult

# %% [markdown]
# ## Data Processing 1 (FULL)
#
# A function to load and process a dataset with multiple features with the following requirements:
#
# + Specify the start date and the end date for the whole
# dataset as inputs.
# + Allowing you to deal with the NaN issue in the data
# + Splitting dataset according to some specified ratio of train/test
# + Storing the downloaded data on your local machine for future uses
# + Allowing you to have an option to scale your feature columns and store the scalers in a data structure to allow future access to these scalers.

# %%
def Data_Processing_1():
    dataLoader = DataLoader()

    scaledStockData = dataLoader["dataset"]
    datasetScaler = dataLoader["datasetScaler"]
    columnScalers = dataLoader["columnScalers"]
    
    dataset = datasetSplitter(dataset=scaledStockData)
    
    print("Loaded Done!\nThe result is a tuple as below:\n")
    print("(dataset, scaledStockData, datasetScaler, columnScalers), where:\n")
    print("dataset is a dictionary as below:")
    print('''{
        "X_training_set": <class 'numpy.ndarray'>,
        "Y_training_set": <class 'numpy.ndarray'>,
    }\n''')
    print("scaledStockData is a Pandas Dataframe of the Stock Ticker (scaled)\n")
    print("datasetScaler is the Scaler of the dataset\n")
    print("columnScalers is a dictionary: each key is a DataFrame Feature('Open', 'High', etc.) and the correspond value is a scaler of that feature")
    return dataset, scaledStockData, datasetScaler, columnScalers

# %% [markdown]
# # Task B5: Machine Learning 2

# %% [markdown]
# ### Inverse Data

# %%
def datasetInverser(scaledStockData, datasetScaler):
    
    # Getting Column name
    col_names = scaledStockData.columns
    # Inversing the dataframe
    re_scaled_features = datasetScaler.inverse_transform(scaledStockData)
    re_scaled_stock_data = pd.DataFrame(re_scaled_features, columns = col_names)
    # Assigning index to the rescaled_data
    re_scaled_stock_data.index = scaledStockData.index


    ## A Pandas Dataframe
    return re_scaled_stock_data

# %% [markdown]
# ### Inversing A Column in the Dataset

# %%
def columnInverser(columnData, ColumnScaler):
    '''columnData: an np.array'''
    # transform the shape of the data
    reshaped_data = columnData.reshape(-1, 1)
    result = ColumnScaler.inverse_transform(reshaped_data)
    return result

# %% [markdown]
# ### Plotting the Loss Error

# %%
def trainingErrorPloter(modelType, loss, validation):
    fig = plt.figure(figsize=(4, 3)) 
    plt.plot(loss, c="red", label = "training set")
    plt.plot(validation, c="blue", label = "validation set")
    plt.legend()
    plt.title(f"Loss Plotting of {modelType} Model")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    return fig

# %% [markdown]
# ### Plotting Metrics

# %%
def MSE_Ploter(modelType ,mse):
    fig = plt.figure(figsize=(4, 3)) 
    plt.plot(mse, c="blue", label = f"MSE")
    plt.legend()
    plt.title(f"Evaluation on {modelType} Model")
    plt.xlabel("Epochs")
    plt.ylabel("Error")
    return fig

# %% [markdown]
# ### Plotting Predicted Result

# %%
def predictedResultPloter(actual_value, RNN_predicted_value, LSTM_predicted_value, GRU_predicted_result, AdvancedLSTM_predicted_result, testingStockData, feature=FEATURE_PREDICT):
    fig = plt.figure(figsize=(15, 8)) 
    plt.plot(testingStockData.index, actual_value, c="orange", label = f"{feature} Price (Actual)")
    plt.plot(testingStockData.index, RNN_predicted_value, c="red", label = f"RNN--{feature} Price (Predicted)")
    plt.plot(testingStockData.index, LSTM_predicted_value, c="green", label = f"LSTM--{feature} Price (Predicted)")
    plt.plot(testingStockData.index, GRU_predicted_result, c="blue", label = f"GRU--{feature} Price (Predicted)")
    plt.plot(testingStockData.index, AdvancedLSTM_predicted_result, c="gray", label = f"AdvancedLSTM--{feature} Price (Predicted)")
    plt.legend()
    plt.title(f"Testing on {TICKER} shared price, LOOK_UP_DAYS={LOOK_UP_DAYS}, Predicting the sequential of {K_SEQUENCE} days")
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    return fig

# %% [markdown]
# ### Result Saver

# %%
def resultSaver(RNNerrorFig, RNNmetrics_MSE, LSTMerrorFig, LSTMmetrics_MSE, GRUerrorFig, GRUmetrics_MSE, AdvancedLSTM_errorFig, AdvancedLSTM_metrics_MSE,predictResult):
    # Get a list of foler in the results folders
    folders = os.listdir("results")


    # Creating a new folder to store the training infomation
    latestFolderName = "Evaluation_K"
    if K_SEQUENCE < 10:
        latestFolderName += ("0" + str(K_SEQUENCE))
    else:
        latestFolderName += str(K_SEQUENCE)
    evaluation_path = os.path.join("results", latestFolderName)
    os.makedirs(evaluation_path)
    # Saving Fig
    RNNerrorFig.savefig(os.path.join(evaluation_path, "RNN_error.png"))
    RNNmetrics_MSE.savefig(os.path.join(evaluation_path, "RNN_metrics_MSE.png"))


    LSTMerrorFig.savefig(os.path.join(evaluation_path, "LSTM_error.png"))
    LSTMmetrics_MSE.savefig(os.path.join(evaluation_path, "LSTM_metrics_MSE.png"))


    GRUerrorFig.savefig(os.path.join(evaluation_path, "GRU_error.png"))
    GRUmetrics_MSE.savefig(os.path.join(evaluation_path, "GRU_metrics_MSE.png"))

    AdvancedLSTM_errorFig.savefig(os.path.join(evaluation_path, "AdvancedLSTM_error.png"))
    AdvancedLSTM_metrics_MSE.savefig(os.path.join(evaluation_path, "AdvancedLSTM_metrics_MSE.png"))

   
    predictResult.savefig(os.path.join(evaluation_path, "PredictResult.png"))

    with open(os.path.join(evaluation_path, "Configuration.txt"), 'w') as file:
        content = f'''
        NUMBER_OF_LAYER = {NUMBER_OF_LAYER} \n
        NUMBER_OF_HIDDEN_UNITS = {NUMBER_OF_HIDDEN_UNITS} \n
        NUMBER_OF_EPOCHS = {NUMBER_OF_EPOCHS}\n
        BATCH_SIZE = {BATCH_SIZE}\n
        FEATURE_PREDICT = "{FEATURE_PREDICT}"\n    
        LOSS_FUNCTION = "{LOSS_FUNCTION}"\n 
        OPTIMIZER = "{OPTIMIZER}"\n  
        DROP_OUT_RATE = {DROP_OUT_RATE}    '''
        
        file.write(content)

# %% [markdown]
# ### Recurrent Neural Networks (RNNs)

# %%
def RecurrentNeuralNetworks(InputLayer,layerNums=NUMBER_OF_LAYER,hidden_units=NUMBER_OF_HIDDEN_UNITS, loss_type=LOSS_FUNCTION, optimizerType=OPTIMIZER, dense_unit=K_SEQUENCE, activation=["tanh", "linear"], dropoutRate = DROP_OUT_RATE):
    model = Sequential()

    for i in range(layerNums):
        if i == (layerNums - 1):
            model.add(InputLayer)
            model.add(SimpleRNN(hidden_units, activation=activation[0]))
            model.add(Dropout(dropoutRate))
        else:
            model.add(SimpleRNN(hidden_units, activation=activation[0], return_sequences=True))
            model.add(Dropout(dropoutRate))

    model.add(Dense(units=dense_unit, activation=activation[1]))
    model.compile(loss=loss_type, metrics=[metrics.MeanSquaredError(), metrics.MeanAbsoluteError(), metrics.R2Score()], optimizer=optimizerType)
    return model

# %% [markdown]
# ### Long Short Term Memory (LSTM)

# %%
def LongShortTermMemory(InputLayer, layerNums=NUMBER_OF_LAYER,hidden_units=NUMBER_OF_HIDDEN_UNITS, loss_type=LOSS_FUNCTION, optimizerType=OPTIMIZER, dense_unit=K_SEQUENCE, activation=["tanh", "linear"], dropoutRate = DROP_OUT_RATE):
    model = Sequential()

    for i in range(layerNums):
        if i == (layerNums - 1):
            model.add(InputLayer)
            model.add(LSTM(hidden_units, activation=activation[0]))
            model.add(Dropout(dropoutRate))
        else:
            model.add(LSTM(hidden_units, activation=activation[0], return_sequences=True))
            model.add(Dropout(dropoutRate))

    model.add(Dense(units=dense_unit, activation=activation[1]))
    model.compile(loss=loss_type, metrics=[metrics.MeanSquaredError(), metrics.MeanAbsoluteError(), metrics.R2Score()], optimizer=optimizerType)
    return model

# %% [markdown]
# ### Gated Recurrent Unit (GRU)

# %%
def GatedRucurrentUnit(InputLayer, layerNums=NUMBER_OF_LAYER,hidden_units=NUMBER_OF_HIDDEN_UNITS, loss_type=LOSS_FUNCTION, optimizerType=OPTIMIZER, dense_unit=K_SEQUENCE, activation=["tanh", "linear"], dropoutRate = DROP_OUT_RATE):
    model = Sequential()

    for i in range(layerNums):
        if i == (layerNums - 1):
            model.add(InputLayer)
            model.add(GRU(hidden_units, activation=activation[0]))
            model.add(Dropout(dropoutRate))
        else:
            model.add(GRU(hidden_units, activation=activation[0], return_sequences=True))
            model.add(Dropout(dropoutRate))

    model.add(Dense(units=dense_unit, activation=activation[1]))
    model.compile(loss=loss_type, metrics=[metrics.MeanSquaredError(), metrics.MeanAbsoluteError(), metrics.R2Score()], optimizer=optimizerType)
    return model

# %% [markdown]
# ### Testing Data Loader

# %%
def testingDataLoader(ticker=TICKER, start_date=START_TEST_DATE, end_date=END_TEST_DATE, end_train_date=END_DATE, scale=SCALE_DATA, scaling_method=SCALING_METHOD, k_days=K_SEQUENCE, feature=FEATURE_PREDICT, look_up_days=LOOK_UP_DAYS):
    result = {
        "testingStockData": None,
        "x_data": None,
        "y_scaled_test": None,
        "y_original_test": None,
        "columnScalers": None
    }
    
    real_stock_data = yf.download(ticker, start_date, end_date)
    # Getting the latest k_days records 
    real_stock_data = real_stock_data.tail(k_days)
    result["testingStockData"] = real_stock_data
    
    # Getting the last look_up_days records
    real_stock_data_back_then = yf.download(ticker, end_train_date, start_date)

    real_stock_data_back_then = real_stock_data_back_then.head(look_up_days)
    
    columns = real_stock_data_back_then.columns.tolist()
    # Scale Data
    if scale:
        x_data = []
        scaledData, scaler, column_scalers = DataScaler(real_stock_data_back_then, scaling_method)
        
        for day in range(look_up_days):
            data_point = []
            for column in columns:
                if column == feature:
                    continue

                data_point.append(scaledData[column].values[day])
            x_data.append(data_point)
        
        
        result["x_data"] = np.array(x_data)
        result["y_scaled_test"] = scaledData[feature].values
        result["y_original_test"] = real_stock_data[feature].values
        result["columnScalers"] = column_scalers
    
    else:
        x_data = []
        for day in range(look_up_days):
            data_point = []
            for column in columns:
                if column == feature:
                    continue

                data_point.append(real_stock_data_back_then[column].values[day])
            x_data.append(data_point)
        
        
        result["x_data"] = np.array(x_data)
        result["y_scaled_test"] = real_stock_data[feature].values
        result["y_original_test"] = real_stock_data[feature].values
        
    # Reshape the input data
    result["x_data"] = result["x_data"].reshape((1, look_up_days, 5))
    return result

# %% [markdown]
# ### Training Function

# %%
def Train(RNNmodel, LSTMmodel, GRUmodel, advancedLSTMmodel, dataset, columnScalers, num_epoc=NUMBER_OF_EPOCHS, batch=BATCH_SIZE):
    

    ## Getting x_train, y_train, x_test, and y_test
    x_train = dataset["X_training_set"]
    y_train = dataset["Y_training_set"]


    # RNN training 
    RNN_training_result = RNNmodel.fit(x_train, y_train, epochs=num_epoc, batch_size=batch, validation_split=0.2)

    ## Plotting the error
    RNNerrorfig = trainingErrorPloter("RNN",RNN_training_result.history["loss"], RNN_training_result.history["val_loss"])
    
    ## Ploting the evaluation Result
    RNN_MSE_Fig = MSE_Ploter("RNN",RNN_training_result.history["mean_squared_error"])


    # LSTM training 
    LSTM_training_result = LSTMmodel.fit(x_train, y_train, epochs=num_epoc, batch_size=batch, validation_split=0.2)

    ## Plotting the error
    LSTMerrorfig = trainingErrorPloter("LSTM",LSTM_training_result.history["loss"], LSTM_training_result.history["val_loss"])
    
    ## Ploting the evaluation Result
    LSTM_MSE_Fig = MSE_Ploter("LSTM", LSTM_training_result.history["mean_squared_error"])


    # GRU training 
    GRU_training_result = GRUmodel.fit(x_train, y_train, epochs=num_epoc, batch_size=batch, validation_split=0.2)

    ## Plotting the error
    GRUerrorfig = trainingErrorPloter("GRU", GRU_training_result.history["loss"], GRU_training_result.history["val_loss"])
    
    ## Ploting the evaluation Result
    GRU_MSE_Fig = MSE_Ploter("GRU", GRU_training_result.history["mean_squared_error"])

    
    # Advanced LSTM training 
    advancedLSTM_training_result = advancedLSTMmodel.fit(x_train, y_train, epochs=num_epoc, batch_size=batch, validation_split=0.2)

    ## Plotting the error
    advancedLSTMerrorfig = trainingErrorPloter("advanced_LSTM",advancedLSTM_training_result.history["loss"], advancedLSTM_training_result.history["val_loss"])
    
    ## Ploting the evaluation Result
    advancedLSTM_MSE_Fig = MSE_Ploter("advanced_LSTM", advancedLSTM_training_result.history["mean_squared_error"])
    
    
    # Testing the result
    testingDatasetLoader = testingDataLoader()
    testing_stock_dataframe = testingDatasetLoader["testingStockData"]
    y_original = testingDatasetLoader["y_original_test"]
    x = testingDatasetLoader["x_data"]

    
    RNN_y_predicted = RNNmodel.predict(x)
    LSTM_y_predicted = LSTMmodel.predict(x)
    GRU_y_predicted = GRUmodel.predict(x)
    AdvancedLSTM_y_predicted = advancedLSTMmodel.predict(x)

    ## Reverse prediction if required
    if SCALE_DATA:
        RNN_y_predicted = RNN_y_predicted.reshape(K_SEQUENCE,)
        RNN_y_predicted = columnInverser(RNN_y_predicted, columnScalers[FEATURE_PREDICT])
        
        
        LSTM_y_predicted = LSTM_y_predicted.reshape(K_SEQUENCE,)
        LSTM_y_predicted = columnInverser(LSTM_y_predicted, columnScalers[FEATURE_PREDICT])
        
        GRU_y_predicted = GRU_y_predicted.reshape(K_SEQUENCE,)
        GRU_y_predicted = columnInverser(GRU_y_predicted, columnScalers[FEATURE_PREDICT])

        AdvancedLSTM_y_predicted = AdvancedLSTM_y_predicted.reshape(K_SEQUENCE,)
        AdvancedLSTM_y_predicted = columnInverser(AdvancedLSTM_y_predicted, columnScalers[FEATURE_PREDICT])


    
    # Plotting predicted result
    predictedResultFigure = predictedResultPloter(y_original, RNN_y_predicted, LSTM_y_predicted, GRU_y_predicted, AdvancedLSTM_y_predicted, testing_stock_dataframe) 
    
    resultSaver(RNNerrorfig, RNN_MSE_Fig, LSTMerrorfig, LSTM_MSE_Fig, GRUerrorfig, GRU_MSE_Fig, advancedLSTMerrorfig, advancedLSTM_MSE_Fig, predictedResultFigure)

# %%
dataset, scaledStockData, datasetScaler, ColumnScalers  = Data_Processing_1()
# Out:
# d:\DELL\Desktop\COS30018\COS30018\ProjectAssessment\TaskB1\myenv\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# Local Stock Data is not enough for requirements, continuing downloading...
# Loaded Done!
# The result is a tuple as below:
#
# (dataset, scaledStockData, datasetScaler, columnScalers), where:
#
# dataset is a dictionary as below:
# {
#         "X_training_set": <class 'numpy.ndarray'>,
#         "Y_training_set": <class 'numpy.ndarray'>,
#     }
#
# scaledStockData is a Pandas Dataframe of the Stock Ticker (scaled)
#
# datasetScaler is the Scaler of the dataset
#
# columnScalers is a dictionary: each key is a DataFrame Feature('Open', 'High', etc.) and the correspond value is a scaler of that feature

# %% [markdown]
# # Task B7: Comprehensive extension and Independent Research

# %%
class ExpectationBiasLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ExpectationBiasLayer, self).__init__(**kwargs)
    
    def call(self, inputs):
        # Assuming 'inputs' shape is [batch, timesteps, features] = [?, 10, 5]
        # And Sequence is the entire inputs for simplicity
        Sequence = inputs
        output = []
        for State in range(1, inputs.shape[1] + 1):  # Starting from 1 to avoid division by zero
            input = inputs[:, State-1, :]  # Current state
            Beta_T = 1 / tf.cast(State, tf.float32)
            e_State = []
            for i in range(inputs.shape[-1]):  # Loop through features
                u_i = tf.reduce_mean(Sequence[:, :State, i], axis=1)  # Mean over the sequence up to current state
                e_i_t = (Beta_T * input[:, i]) + (1 - Beta_T) * u_i
                e_State.append(e_i_t)
            e_State = tf.stack(e_State, axis=1)
            output.append(e_State)
        output = tf.stack(output, axis=1)
        return output

def AdvancedLSTM(InputLayer,hidden_units=NUMBER_OF_HIDDEN_UNITS, loss_type=LOSS_FUNCTION, optimizerType=OPTIMIZER, dense_unit=K_SEQUENCE):
    expectation_layer = ExpectationBiasLayer()(InputLayer)
    lstm_layer = tf.keras.layers.LSTM(hidden_units, return_sequences=False)(expectation_layer)
    output_layer = tf.keras.layers.Dense(dense_unit)(lstm_layer)  

    model = tf.keras.Model(inputs=InputLayer, outputs=output_layer)
    model.compile(optimizer=optimizerType, loss=loss_type, metrics=[metrics.MeanSquaredError(), metrics.MeanAbsoluteError(), metrics.R2Score()])

    return model

# %%
def TaskB7_ComprehensiveExtension(dataset=dataset, column_scalers=ColumnScalers):

    inputLayer = tf.keras.Input(shape=(dataset["X_training_set"].shape[1],dataset["X_training_set"].shape[2]), batch_size=dataset["X_training_set"].shape[0])
    

    RNNmodel = RecurrentNeuralNetworks(inputLayer)


    LSTMmodel = LongShortTermMemory(inputLayer)
    

    GRUmodel = GatedRucurrentUnit(inputLayer)


    AdvancedLSTMmodel = AdvancedLSTM(inputLayer)
    ## Performing Training and getting result
    Train(RNNmodel, LSTMmodel, GRUmodel, AdvancedLSTMmodel, dataset, column_scalers)

# %%
TaskB7_ComprehensiveExtension()
# Out:
# Epoch 1/30
# 81/81 [==============================] - 3s 14ms/step - loss: 0.0067 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0607 - r2_score: -0.5736 - val_loss: 0.0447 - val_mean_squared_error: 0.0894 - val_mean_absolute_error: 0.2592 - val_r2_score: -4.5661
# Epoch 2/30
# 81/81 [==============================] - 1s 10ms/step - loss: 2.9723e-04 - mean_squared_error: 5.9445e-04 - mean_absolute_error: 0.0184 - r2_score: 0.9310 - val_loss: 0.0365 - val_mean_squared_error: 0.0731 - val_mean_absolute_error: 0.2368 - val_r2_score: -3.5450
# Epoch 3/30
# 81/81 [==============================] - 1s 8ms/step - loss: 2.2274e-04 - mean_squared_error: 4.4549e-04 - mean_absolute_error: 0.0157 - r2_score: 0.9483 - val_loss: 0.0301 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2098 - val_r2_score: -2.7508
# Epoch 4/30
# 81/81 [==============================] - 1s 8ms/step - loss: 2.3874e-04 - mean_squared_error: 4.7748e-04 - mean_absolute_error: 0.0165 - r2_score: 0.9446 - val_loss: 0.0271 - val_mean_squared_error: 0.0542 - val_mean_absolute_error: 0.1931 - val_r2_score: -2.3711
# Epoch 5/30
# 81/81 [==============================] - 1s 8ms/step - loss: 2.1238e-04 - mean_squared_error: 4.2476e-04 - mean_absolute_error: 0.0152 - r2_score: 0.9508 - val_loss: 0.0258 - val_mean_squared_error: 0.0516 - val_mean_absolute_error: 0.1886 - val_r2_score: -2.2074
# Epoch 6/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.9042e-04 - mean_squared_error: 3.8084e-04 - mean_absolute_error: 0.0143 - r2_score: 0.9559 - val_loss: 0.0249 - val_mean_squared_error: 0.0499 - val_mean_absolute_error: 0.1856 - val_r2_score: -2.0957
# Epoch 7/30
# 81/81 [==============================] - 1s 9ms/step - loss: 2.1315e-04 - mean_squared_error: 4.2630e-04 - mean_absolute_error: 0.0155 - r2_score: 0.9506 - val_loss: 0.0264 - val_mean_squared_error: 0.0527 - val_mean_absolute_error: 0.1940 - val_r2_score: -2.2644
# Epoch 8/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.7541e-04 - mean_squared_error: 3.5082e-04 - mean_absolute_error: 0.0138 - r2_score: 0.9593 - val_loss: 0.0273 - val_mean_squared_error: 0.0545 - val_mean_absolute_error: 0.1978 - val_r2_score: -2.3825
# Epoch 9/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.7938e-04 - mean_squared_error: 3.5876e-04 - mean_absolute_error: 0.0141 - r2_score: 0.9584 - val_loss: 0.0273 - val_mean_squared_error: 0.0545 - val_mean_absolute_error: 0.1963 - val_r2_score: -2.3849
# Epoch 10/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.6321e-04 - mean_squared_error: 3.2642e-04 - mean_absolute_error: 0.0131 - r2_score: 0.9622 - val_loss: 0.0264 - val_mean_squared_error: 0.0529 - val_mean_absolute_error: 0.1949 - val_r2_score: -2.2747
# Epoch 11/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.5274e-04 - mean_squared_error: 3.0548e-04 - mean_absolute_error: 0.0128 - r2_score: 0.9646 - val_loss: 0.0271 - val_mean_squared_error: 0.0542 - val_mean_absolute_error: 0.2000 - val_r2_score: -2.3485
# Epoch 12/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.4725e-04 - mean_squared_error: 2.9450e-04 - mean_absolute_error: 0.0123 - r2_score: 0.9659 - val_loss: 0.0289 - val_mean_squared_error: 0.0578 - val_mean_absolute_error: 0.2110 - val_r2_score: -2.5805
# Epoch 13/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.9110e-04 - mean_squared_error: 3.8219e-04 - mean_absolute_error: 0.0143 - r2_score: 0.9557 - val_loss: 0.0269 - val_mean_squared_error: 0.0537 - val_mean_absolute_error: 0.1950 - val_r2_score: -2.3362
# Epoch 14/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.5724e-04 - mean_squared_error: 3.1448e-04 - mean_absolute_error: 0.0132 - r2_score: 0.9636 - val_loss: 0.0284 - val_mean_squared_error: 0.0568 - val_mean_absolute_error: 0.2033 - val_r2_score: -2.5283
# Epoch 15/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.5151e-04 - mean_squared_error: 3.0302e-04 - mean_absolute_error: 0.0128 - r2_score: 0.9649 - val_loss: 0.0284 - val_mean_squared_error: 0.0567 - val_mean_absolute_error: 0.2011 - val_r2_score: -2.5200
# Epoch 16/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3823e-04 - mean_squared_error: 2.7647e-04 - mean_absolute_error: 0.0121 - r2_score: 0.9680 - val_loss: 0.0275 - val_mean_squared_error: 0.0550 - val_mean_absolute_error: 0.1988 - val_r2_score: -2.4070
# Epoch 17/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3006e-04 - mean_squared_error: 2.6012e-04 - mean_absolute_error: 0.0117 - r2_score: 0.9699 - val_loss: 0.0273 - val_mean_squared_error: 0.0547 - val_mean_absolute_error: 0.2010 - val_r2_score: -2.3887
# Epoch 18/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3165e-04 - mean_squared_error: 2.6330e-04 - mean_absolute_error: 0.0119 - r2_score: 0.9695 - val_loss: 0.0268 - val_mean_squared_error: 0.0537 - val_mean_absolute_error: 0.1972 - val_r2_score: -2.3336
# Epoch 19/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.1956e-04 - mean_squared_error: 2.3911e-04 - mean_absolute_error: 0.0111 - r2_score: 0.9723 - val_loss: 0.0263 - val_mean_squared_error: 0.0526 - val_mean_absolute_error: 0.1940 - val_r2_score: -2.2611
# Epoch 20/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.4786e-04 - mean_squared_error: 2.9571e-04 - mean_absolute_error: 0.0128 - r2_score: 0.9657 - val_loss: 0.0244 - val_mean_squared_error: 0.0488 - val_mean_absolute_error: 0.1837 - val_r2_score: -2.0349
# Epoch 21/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3097e-04 - mean_squared_error: 2.6193e-04 - mean_absolute_error: 0.0117 - r2_score: 0.9696 - val_loss: 0.0259 - val_mean_squared_error: 0.0518 - val_mean_absolute_error: 0.1936 - val_r2_score: -2.2118
# Epoch 22/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.4400e-04 - mean_squared_error: 2.8801e-04 - mean_absolute_error: 0.0123 - r2_score: 0.9666 - val_loss: 0.0276 - val_mean_squared_error: 0.0552 - val_mean_absolute_error: 0.2024 - val_r2_score: -2.4366
# Epoch 23/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.5963e-04 - mean_squared_error: 3.1926e-04 - mean_absolute_error: 0.0131 - r2_score: 0.9630 - val_loss: 0.0279 - val_mean_squared_error: 0.0558 - val_mean_absolute_error: 0.2049 - val_r2_score: -2.4682
# Epoch 24/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.6380e-04 - mean_squared_error: 3.2760e-04 - mean_absolute_error: 0.0134 - r2_score: 0.9620 - val_loss: 0.0276 - val_mean_squared_error: 0.0552 - val_mean_absolute_error: 0.2028 - val_r2_score: -2.4342
# Epoch 25/30
# 81/81 [==============================] - 1s 11ms/step - loss: 1.2600e-04 - mean_squared_error: 2.5200e-04 - mean_absolute_error: 0.0115 - r2_score: 0.9708 - val_loss: 0.0280 - val_mean_squared_error: 0.0560 - val_mean_absolute_error: 0.2016 - val_r2_score: -2.4842
# Epoch 26/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.5002e-04 - mean_squared_error: 3.0004e-04 - mean_absolute_error: 0.0129 - r2_score: 0.9652 - val_loss: 0.0272 - val_mean_squared_error: 0.0545 - val_mean_absolute_error: 0.1997 - val_r2_score: -2.3857
# Epoch 27/30
# 81/81 [==============================] - 1s 11ms/step - loss: 1.3585e-04 - mean_squared_error: 2.7171e-04 - mean_absolute_error: 0.0122 - r2_score: 0.9685 - val_loss: 0.0291 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.2115 - val_r2_score: -2.6134
# Epoch 28/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.1718e-04 - mean_squared_error: 2.3436e-04 - mean_absolute_error: 0.0110 - r2_score: 0.9729 - val_loss: 0.0282 - val_mean_squared_error: 0.0564 - val_mean_absolute_error: 0.2050 - val_r2_score: -2.5191
# Epoch 29/30
# 81/81 [==============================] - 1s 11ms/step - loss: 9.9721e-05 - mean_squared_error: 1.9944e-04 - mean_absolute_error: 0.0098 - r2_score: 0.9769 - val_loss: 0.0279 - val_mean_squared_error: 0.0557 - val_mean_absolute_error: 0.2011 - val_r2_score: -2.4784
# Epoch 30/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.1184e-04 - mean_squared_error: 2.2368e-04 - mean_absolute_error: 0.0106 - r2_score: 0.9741 - val_loss: 0.0273 - val_mean_squared_error: 0.0545 - val_mean_absolute_error: 0.1970 - val_r2_score: -2.4037
# Epoch 1/30
# 81/81 [==============================] - 8s 37ms/step - loss: 0.0011 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0267 - r2_score: 0.7399 - val_loss: 0.0120 - val_mean_squared_error: 0.0240 - val_mean_absolute_error: 0.1342 - val_r2_score: -0.4594
# Epoch 2/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.5196e-04 - mean_squared_error: 3.0391e-04 - mean_absolute_error: 0.0111 - r2_score: 0.9648 - val_loss: 0.0200 - val_mean_squared_error: 0.0400 - val_mean_absolute_error: 0.1823 - val_r2_score: -1.4415
# Epoch 3/30
# 81/81 [==============================] - 2s 23ms/step - loss: 1.3857e-04 - mean_squared_error: 2.7714e-04 - mean_absolute_error: 0.0106 - r2_score: 0.9679 - val_loss: 0.0187 - val_mean_squared_error: 0.0374 - val_mean_absolute_error: 0.1769 - val_r2_score: -1.2840
# Epoch 4/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.4119e-04 - mean_squared_error: 2.8238e-04 - mean_absolute_error: 0.0110 - r2_score: 0.9673 - val_loss: 0.0159 - val_mean_squared_error: 0.0319 - val_mean_absolute_error: 0.1605 - val_r2_score: -0.9479
# Epoch 5/30
# 81/81 [==============================] - 2s 23ms/step - loss: 1.3065e-04 - mean_squared_error: 2.6129e-04 - mean_absolute_error: 0.0105 - r2_score: 0.9697 - val_loss: 0.0146 - val_mean_squared_error: 0.0293 - val_mean_absolute_error: 0.1530 - val_r2_score: -0.7827
# Epoch 6/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.2894e-04 - mean_squared_error: 2.5787e-04 - mean_absolute_error: 0.0103 - r2_score: 0.9701 - val_loss: 0.0129 - val_mean_squared_error: 0.0258 - val_mean_absolute_error: 0.1430 - val_r2_score: -0.5743
# Epoch 7/30
# 81/81 [==============================] - 2s 24ms/step - loss: 1.3704e-04 - mean_squared_error: 2.7408e-04 - mean_absolute_error: 0.0108 - r2_score: 0.9682 - val_loss: 0.0177 - val_mean_squared_error: 0.0354 - val_mean_absolute_error: 0.1724 - val_r2_score: -1.1706
# Epoch 8/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.1874e-04 - mean_squared_error: 2.3749e-04 - mean_absolute_error: 0.0102 - r2_score: 0.9725 - val_loss: 0.0111 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.1305 - val_r2_score: -0.3559
# Epoch 9/30
# 81/81 [==============================] - 2s 24ms/step - loss: 1.2543e-04 - mean_squared_error: 2.5087e-04 - mean_absolute_error: 0.0102 - r2_score: 0.9709 - val_loss: 0.0125 - val_mean_squared_error: 0.0249 - val_mean_absolute_error: 0.1422 - val_r2_score: -0.5348
# Epoch 10/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.2443e-04 - mean_squared_error: 2.4886e-04 - mean_absolute_error: 0.0104 - r2_score: 0.9712 - val_loss: 0.0161 - val_mean_squared_error: 0.0321 - val_mean_absolute_error: 0.1649 - val_r2_score: -0.9645
# Epoch 11/30
# 81/81 [==============================] - 2s 23ms/step - loss: 1.1262e-04 - mean_squared_error: 2.2523e-04 - mean_absolute_error: 0.0100 - r2_score: 0.9739 - val_loss: 0.0126 - val_mean_squared_error: 0.0253 - val_mean_absolute_error: 0.1439 - val_r2_score: -0.5485
# Epoch 12/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.2076e-04 - mean_squared_error: 2.4151e-04 - mean_absolute_error: 0.0102 - r2_score: 0.9720 - val_loss: 0.0102 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.1252 - val_r2_score: -0.2555
# Epoch 13/30
# 81/81 [==============================] - 2s 24ms/step - loss: 1.0944e-04 - mean_squared_error: 2.1887e-04 - mean_absolute_error: 0.0096 - r2_score: 0.9747 - val_loss: 0.0110 - val_mean_squared_error: 0.0221 - val_mean_absolute_error: 0.1320 - val_r2_score: -0.3543
# Epoch 14/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.0035e-04 - mean_squared_error: 2.0069e-04 - mean_absolute_error: 0.0091 - r2_score: 0.9768 - val_loss: 0.0097 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1225 - val_r2_score: -0.1990
# Epoch 15/30
# 81/81 [==============================] - 2s 23ms/step - loss: 9.3962e-05 - mean_squared_error: 1.8792e-04 - mean_absolute_error: 0.0088 - r2_score: 0.9783 - val_loss: 0.0135 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.1487 - val_r2_score: -0.6541
# Epoch 16/30
# 81/81 [==============================] - 2s 22ms/step - loss: 9.2864e-05 - mean_squared_error: 1.8573e-04 - mean_absolute_error: 0.0089 - r2_score: 0.9785 - val_loss: 0.0128 - val_mean_squared_error: 0.0256 - val_mean_absolute_error: 0.1449 - val_r2_score: -0.5822
# Epoch 17/30
# 81/81 [==============================] - 2s 23ms/step - loss: 1.0694e-04 - mean_squared_error: 2.1388e-04 - mean_absolute_error: 0.0096 - r2_score: 0.9752 - val_loss: 0.0159 - val_mean_squared_error: 0.0319 - val_mean_absolute_error: 0.1661 - val_r2_score: -0.9509
# Epoch 18/30
# 81/81 [==============================] - 2s 22ms/step - loss: 1.0338e-04 - mean_squared_error: 2.0677e-04 - mean_absolute_error: 0.0093 - r2_score: 0.9761 - val_loss: 0.0087 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.1163 - val_r2_score: -0.0721
# Epoch 19/30
# 81/81 [==============================] - 2s 23ms/step - loss: 9.2831e-05 - mean_squared_error: 1.8566e-04 - mean_absolute_error: 0.0088 - r2_score: 0.9785 - val_loss: 0.0102 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.1237 - val_r2_score: -0.2742
# Epoch 20/30
# 81/81 [==============================] - 2s 22ms/step - loss: 8.7258e-05 - mean_squared_error: 1.7452e-04 - mean_absolute_error: 0.0085 - r2_score: 0.9798 - val_loss: 0.0168 - val_mean_squared_error: 0.0336 - val_mean_absolute_error: 0.1641 - val_r2_score: -1.0884
# Epoch 21/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.6020e-05 - mean_squared_error: 1.7204e-04 - mean_absolute_error: 0.0086 - r2_score: 0.9801 - val_loss: 0.0336 - val_mean_squared_error: 0.0672 - val_mean_absolute_error: 0.2393 - val_r2_score: -3.1551
# Epoch 22/30
# 81/81 [==============================] - 2s 22ms/step - loss: 8.3264e-05 - mean_squared_error: 1.6653e-04 - mean_absolute_error: 0.0084 - r2_score: 0.9807 - val_loss: 0.0170 - val_mean_squared_error: 0.0340 - val_mean_absolute_error: 0.1608 - val_r2_score: -1.1300
# Epoch 23/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.3308e-05 - mean_squared_error: 1.6662e-04 - mean_absolute_error: 0.0085 - r2_score: 0.9807 - val_loss: 0.0117 - val_mean_squared_error: 0.0234 - val_mean_absolute_error: 0.1323 - val_r2_score: -0.4579
# Epoch 24/30
# 81/81 [==============================] - 2s 22ms/step - loss: 8.2809e-05 - mean_squared_error: 1.6562e-04 - mean_absolute_error: 0.0085 - r2_score: 0.9808 - val_loss: 0.0301 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2227 - val_r2_score: -2.7678
# Epoch 25/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.3174e-05 - mean_squared_error: 1.6635e-04 - mean_absolute_error: 0.0084 - r2_score: 0.9808 - val_loss: 0.0345 - val_mean_squared_error: 0.0690 - val_mean_absolute_error: 0.2363 - val_r2_score: -3.3025
# Epoch 26/30
# 81/81 [==============================] - 2s 22ms/step - loss: 8.8574e-05 - mean_squared_error: 1.7715e-04 - mean_absolute_error: 0.0088 - r2_score: 0.9795 - val_loss: 0.0098 - val_mean_squared_error: 0.0195 - val_mean_absolute_error: 0.1165 - val_r2_score: -0.2267
# Epoch 27/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.7302e-05 - mean_squared_error: 1.7460e-04 - mean_absolute_error: 0.0088 - r2_score: 0.9798 - val_loss: 0.0334 - val_mean_squared_error: 0.0668 - val_mean_absolute_error: 0.2325 - val_r2_score: -3.1861
# Epoch 28/30
# 81/81 [==============================] - 2s 24ms/step - loss: 7.9862e-05 - mean_squared_error: 1.5972e-04 - mean_absolute_error: 0.0084 - r2_score: 0.9815 - val_loss: 0.0423 - val_mean_squared_error: 0.0845 - val_mean_absolute_error: 0.2644 - val_r2_score: -4.3152
# Epoch 29/30
# 81/81 [==============================] - 2s 22ms/step - loss: 7.4557e-05 - mean_squared_error: 1.4911e-04 - mean_absolute_error: 0.0081 - r2_score: 0.9828 - val_loss: 0.0407 - val_mean_squared_error: 0.0814 - val_mean_absolute_error: 0.2616 - val_r2_score: -4.0812
# Epoch 30/30
# 81/81 [==============================] - 2s 23ms/step - loss: 7.2031e-05 - mean_squared_error: 1.4406e-04 - mean_absolute_error: 0.0080 - r2_score: 0.9833 - val_loss: 0.0205 - val_mean_squared_error: 0.0410 - val_mean_absolute_error: 0.1748 - val_r2_score: -1.5952
# Epoch 1/30
# 81/81 [==============================] - 8s 34ms/step - loss: 0.0010 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0255 - r2_score: 0.7578 - val_loss: 0.0049 - val_mean_squared_error: 0.0098 - val_mean_absolute_error: 0.0852 - val_r2_score: 0.3963
# Epoch 2/30
# 81/81 [==============================] - 2s 23ms/step - loss: 9.8318e-05 - mean_squared_error: 1.9664e-04 - mean_absolute_error: 0.0090 - r2_score: 0.9773 - val_loss: 0.0031 - val_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0653 - val_r2_score: 0.6159
# Epoch 3/30
# 81/81 [==============================] - 2s 21ms/step - loss: 9.9111e-05 - mean_squared_error: 1.9822e-04 - mean_absolute_error: 0.0091 - r2_score: 0.9771 - val_loss: 0.0020 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0492 - val_r2_score: 0.7543
# Epoch 4/30
# 81/81 [==============================] - 2s 22ms/step - loss: 9.2437e-05 - mean_squared_error: 1.8487e-04 - mean_absolute_error: 0.0087 - r2_score: 0.9786 - val_loss: 0.0040 - val_mean_squared_error: 0.0081 - val_mean_absolute_error: 0.0767 - val_r2_score: 0.5047
# Epoch 5/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.7506e-05 - mean_squared_error: 1.7501e-04 - mean_absolute_error: 0.0085 - r2_score: 0.9798 - val_loss: 0.0017 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0457 - val_r2_score: 0.7923
# Epoch 6/30
# 81/81 [==============================] - 2s 25ms/step - loss: 9.0899e-05 - mean_squared_error: 1.8180e-04 - mean_absolute_error: 0.0088 - r2_score: 0.9790 - val_loss: 0.0025 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0553 - val_r2_score: 0.6930
# Epoch 7/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.3229e-05 - mean_squared_error: 1.6646e-04 - mean_absolute_error: 0.0083 - r2_score: 0.9808 - val_loss: 0.0028 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0614 - val_r2_score: 0.6472
# Epoch 8/30
# 81/81 [==============================] - 2s 22ms/step - loss: 9.3229e-05 - mean_squared_error: 1.8646e-04 - mean_absolute_error: 0.0089 - r2_score: 0.9784 - val_loss: 0.0026 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0574 - val_r2_score: 0.6832
# Epoch 9/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.3665e-05 - mean_squared_error: 1.6733e-04 - mean_absolute_error: 0.0084 - r2_score: 0.9807 - val_loss: 0.0023 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0533 - val_r2_score: 0.7168
# Epoch 10/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.4784e-05 - mean_squared_error: 1.6957e-04 - mean_absolute_error: 0.0086 - r2_score: 0.9804 - val_loss: 0.0023 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0549 - val_r2_score: 0.7138
# Epoch 11/30
# 81/81 [==============================] - 2s 22ms/step - loss: 8.0370e-05 - mean_squared_error: 1.6074e-04 - mean_absolute_error: 0.0082 - r2_score: 0.9814 - val_loss: 0.0022 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0545 - val_r2_score: 0.7246
# Epoch 12/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.4095e-05 - mean_squared_error: 1.6819e-04 - mean_absolute_error: 0.0085 - r2_score: 0.9806 - val_loss: 0.0036 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0709 - val_r2_score: 0.5589
# Epoch 13/30
# 81/81 [==============================] - 2s 21ms/step - loss: 7.8179e-05 - mean_squared_error: 1.5636e-04 - mean_absolute_error: 0.0080 - r2_score: 0.9819 - val_loss: 0.0028 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0607 - val_r2_score: 0.6539
# Epoch 14/30
# 81/81 [==============================] - 2s 23ms/step - loss: 7.9224e-05 - mean_squared_error: 1.5845e-04 - mean_absolute_error: 0.0082 - r2_score: 0.9817 - val_loss: 0.0036 - val_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0708 - val_r2_score: 0.5525
# Epoch 15/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.5353e-05 - mean_squared_error: 1.7071e-04 - mean_absolute_error: 0.0086 - r2_score: 0.9803 - val_loss: 0.0019 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0483 - val_r2_score: 0.7601
# Epoch 16/30
# 81/81 [==============================] - 2s 22ms/step - loss: 9.1426e-05 - mean_squared_error: 1.8285e-04 - mean_absolute_error: 0.0091 - r2_score: 0.9789 - val_loss: 0.0044 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0818 - val_r2_score: 0.4521
# Epoch 17/30
# 81/81 [==============================] - 2s 23ms/step - loss: 9.6923e-05 - mean_squared_error: 1.9385e-04 - mean_absolute_error: 0.0095 - r2_score: 0.9776 - val_loss: 0.0036 - val_mean_squared_error: 0.0073 - val_mean_absolute_error: 0.0705 - val_r2_score: 0.5461
# Epoch 18/30
# 81/81 [==============================] - 2s 23ms/step - loss: 8.0498e-05 - mean_squared_error: 1.6100e-04 - mean_absolute_error: 0.0082 - r2_score: 0.9814 - val_loss: 0.0030 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0634 - val_r2_score: 0.6225
# Epoch 19/30
# 81/81 [==============================] - 2s 21ms/step - loss: 8.4112e-05 - mean_squared_error: 1.6822e-04 - mean_absolute_error: 0.0083 - r2_score: 0.9806 - val_loss: 0.0030 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0626 - val_r2_score: 0.6279
# Epoch 20/30
# 81/81 [==============================] - 2s 22ms/step - loss: 7.5640e-05 - mean_squared_error: 1.5128e-04 - mean_absolute_error: 0.0080 - r2_score: 0.9825 - val_loss: 0.0028 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0615 - val_r2_score: 0.6550
# Epoch 21/30
# 81/81 [==============================] - 2s 22ms/step - loss: 7.8475e-05 - mean_squared_error: 1.5695e-04 - mean_absolute_error: 0.0081 - r2_score: 0.9819 - val_loss: 0.0013 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0398 - val_r2_score: 0.8332
# Epoch 22/30
# 81/81 [==============================] - 2s 22ms/step - loss: 7.5196e-05 - mean_squared_error: 1.5039e-04 - mean_absolute_error: 0.0078 - r2_score: 0.9826 - val_loss: 0.0018 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0461 - val_r2_score: 0.7815
# Epoch 23/30
# 81/81 [==============================] - 2s 22ms/step - loss: 7.4803e-05 - mean_squared_error: 1.4961e-04 - mean_absolute_error: 0.0079 - r2_score: 0.9827 - val_loss: 0.0020 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0496 - val_r2_score: 0.7522
# Epoch 24/30
# 81/81 [==============================] - 2s 21ms/step - loss: 7.7829e-05 - mean_squared_error: 1.5566e-04 - mean_absolute_error: 0.0081 - r2_score: 0.9820 - val_loss: 0.0050 - val_mean_squared_error: 0.0101 - val_mean_absolute_error: 0.0881 - val_r2_score: 0.3796
# Epoch 25/30
# 81/81 [==============================] - 2s 22ms/step - loss: 8.3245e-05 - mean_squared_error: 1.6649e-04 - mean_absolute_error: 0.0086 - r2_score: 0.9807 - val_loss: 0.0013 - val_mean_squared_error: 0.0026 - val_mean_absolute_error: 0.0394 - val_r2_score: 0.8378
# Epoch 26/30
# 81/81 [==============================] - 2s 22ms/step - loss: 7.4261e-05 - mean_squared_error: 1.4852e-04 - mean_absolute_error: 0.0079 - r2_score: 0.9828 - val_loss: 0.0024 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0563 - val_r2_score: 0.7060
# Epoch 27/30
# 81/81 [==============================] - 2s 21ms/step - loss: 7.3945e-05 - mean_squared_error: 1.4789e-04 - mean_absolute_error: 0.0077 - r2_score: 0.9829 - val_loss: 0.0025 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0565 - val_r2_score: 0.6912
# Epoch 28/30
# 81/81 [==============================] - 2s 23ms/step - loss: 7.2139e-05 - mean_squared_error: 1.4428e-04 - mean_absolute_error: 0.0076 - r2_score: 0.9833 - val_loss: 0.0024 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0570 - val_r2_score: 0.6991
# Epoch 29/30
# 81/81 [==============================] - 2s 22ms/step - loss: 7.2390e-05 - mean_squared_error: 1.4478e-04 - mean_absolute_error: 0.0076 - r2_score: 0.9833 - val_loss: 0.0033 - val_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0675 - val_r2_score: 0.5949
# Epoch 30/30
# 81/81 [==============================] - 2s 21ms/step - loss: 7.4018e-05 - mean_squared_error: 1.4804e-04 - mean_absolute_error: 0.0079 - r2_score: 0.9829 - val_loss: 0.0021 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0520 - val_r2_score: 0.7386
# Epoch 1/30
# 81/81 [==============================] - 8s 43ms/step - loss: 8.8023e-04 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0231 - r2_score: 0.7953 - val_loss: 0.0076 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.1042 - val_r2_score: 0.0607
# Epoch 2/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.5809e-04 - mean_squared_error: 3.1617e-04 - mean_absolute_error: 0.0114 - r2_score: 0.9633 - val_loss: 0.0102 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.1260 - val_r2_score: -0.2578
# Epoch 3/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.4641e-04 - mean_squared_error: 2.9282e-04 - mean_absolute_error: 0.0109 - r2_score: 0.9661 - val_loss: 0.0104 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.1282 - val_r2_score: -0.2705
# Epoch 4/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.4159e-04 - mean_squared_error: 2.8319e-04 - mean_absolute_error: 0.0107 - r2_score: 0.9672 - val_loss: 0.0071 - val_mean_squared_error: 0.0143 - val_mean_absolute_error: 0.1003 - val_r2_score: 0.1201
# Epoch 5/30
# 81/81 [==============================] - 1s 7ms/step - loss: 1.5920e-04 - mean_squared_error: 3.1841e-04 - mean_absolute_error: 0.0116 - r2_score: 0.9631 - val_loss: 0.0097 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.1219 - val_r2_score: -0.1958
# Epoch 6/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3491e-04 - mean_squared_error: 2.6981e-04 - mean_absolute_error: 0.0103 - r2_score: 0.9687 - val_loss: 0.0068 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0988 - val_r2_score: 0.1591
# Epoch 7/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3553e-04 - mean_squared_error: 2.7105e-04 - mean_absolute_error: 0.0104 - r2_score: 0.9686 - val_loss: 0.0059 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0898 - val_r2_score: 0.2723
# Epoch 8/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3483e-04 - mean_squared_error: 2.6966e-04 - mean_absolute_error: 0.0103 - r2_score: 0.9688 - val_loss: 0.0072 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.1030 - val_r2_score: 0.1050
# Epoch 9/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3085e-04 - mean_squared_error: 2.6170e-04 - mean_absolute_error: 0.0102 - r2_score: 0.9697 - val_loss: 0.0059 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0905 - val_r2_score: 0.2646
# Epoch 10/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.3379e-04 - mean_squared_error: 2.6757e-04 - mean_absolute_error: 0.0103 - r2_score: 0.9690 - val_loss: 0.0062 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0947 - val_r2_score: 0.2289
# Epoch 11/30
# 81/81 [==============================] - 1s 8ms/step - loss: 1.2991e-04 - mean_squared_error: 2.5982e-04 - mean_absolute_error: 0.0102 - r2_score: 0.9699 - val_loss: 0.0053 - val_mean_squared_error: 0.0106 - val_mean_absolute_error: 0.0845 - val_r2_score: 0.3390
# Epoch 12/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.2854e-04 - mean_squared_error: 2.5708e-04 - mean_absolute_error: 0.0104 - r2_score: 0.9702 - val_loss: 0.0038 - val_mean_squared_error: 0.0075 - val_mean_absolute_error: 0.0691 - val_r2_score: 0.5282
# Epoch 13/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.3218e-04 - mean_squared_error: 2.6436e-04 - mean_absolute_error: 0.0103 - r2_score: 0.9694 - val_loss: 0.0048 - val_mean_squared_error: 0.0095 - val_mean_absolute_error: 0.0795 - val_r2_score: 0.4034
# Epoch 14/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.2685e-04 - mean_squared_error: 2.5369e-04 - mean_absolute_error: 0.0102 - r2_score: 0.9706 - val_loss: 0.0063 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0946 - val_r2_score: 0.2051
# Epoch 15/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.2510e-04 - mean_squared_error: 2.5020e-04 - mean_absolute_error: 0.0099 - r2_score: 0.9710 - val_loss: 0.0032 - val_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0630 - val_r2_score: 0.5985
# Epoch 16/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.1746e-04 - mean_squared_error: 2.3492e-04 - mean_absolute_error: 0.0099 - r2_score: 0.9728 - val_loss: 0.0069 - val_mean_squared_error: 0.0139 - val_mean_absolute_error: 0.1013 - val_r2_score: 0.1464
# Epoch 17/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.2360e-04 - mean_squared_error: 2.4719e-04 - mean_absolute_error: 0.0101 - r2_score: 0.9714 - val_loss: 0.0125 - val_mean_squared_error: 0.0250 - val_mean_absolute_error: 0.1403 - val_r2_score: -0.5368
# Epoch 18/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.1209e-04 - mean_squared_error: 2.2419e-04 - mean_absolute_error: 0.0096 - r2_score: 0.9741 - val_loss: 0.0097 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1138 - val_r2_score: -0.1821
# Epoch 19/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.0915e-04 - mean_squared_error: 2.1829e-04 - mean_absolute_error: 0.0095 - r2_score: 0.9747 - val_loss: 0.0211 - val_mean_squared_error: 0.0422 - val_mean_absolute_error: 0.1599 - val_r2_score: -1.5543
# Epoch 20/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.0479e-04 - mean_squared_error: 2.0958e-04 - mean_absolute_error: 0.0093 - r2_score: 0.9757 - val_loss: 0.0235 - val_mean_squared_error: 0.0469 - val_mean_absolute_error: 0.1806 - val_r2_score: -1.8519
# Epoch 21/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.0731e-04 - mean_squared_error: 2.1462e-04 - mean_absolute_error: 0.0096 - r2_score: 0.9752 - val_loss: 0.0732 - val_mean_squared_error: 0.1465 - val_mean_absolute_error: 0.2977 - val_r2_score: -7.8788
# Epoch 22/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.0295e-04 - mean_squared_error: 2.0591e-04 - mean_absolute_error: 0.0093 - r2_score: 0.9762 - val_loss: 0.0829 - val_mean_squared_error: 0.1659 - val_mean_absolute_error: 0.3177 - val_r2_score: -9.0463
# Epoch 23/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.0198e-04 - mean_squared_error: 2.0395e-04 - mean_absolute_error: 0.0093 - r2_score: 0.9764 - val_loss: 0.0194 - val_mean_squared_error: 0.0388 - val_mean_absolute_error: 0.1509 - val_r2_score: -1.3882
# Epoch 24/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.0666e-04 - mean_squared_error: 2.1333e-04 - mean_absolute_error: 0.0094 - r2_score: 0.9753 - val_loss: 0.0837 - val_mean_squared_error: 0.1675 - val_mean_absolute_error: 0.3174 - val_r2_score: -9.1610
# Epoch 25/30
# 81/81 [==============================] - 1s 10ms/step - loss: 1.0608e-04 - mean_squared_error: 2.1217e-04 - mean_absolute_error: 0.0095 - r2_score: 0.9754 - val_loss: 0.1493 - val_mean_squared_error: 0.3003 - val_mean_absolute_error: 0.4297 - val_r2_score: -17.2526
# Epoch 26/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.0390e-04 - mean_squared_error: 2.0780e-04 - mean_absolute_error: 0.0092 - r2_score: 0.9759 - val_loss: 0.1670 - val_mean_squared_error: 0.3372 - val_mean_absolute_error: 0.4555 - val_r2_score: -19.5196
# Epoch 27/30
# 81/81 [==============================] - 1s 9ms/step - loss: 1.0400e-04 - mean_squared_error: 2.0800e-04 - mean_absolute_error: 0.0094 - r2_score: 0.9759 - val_loss: 0.1955 - val_mean_squared_error: 0.3965 - val_mean_absolute_error: 0.5048 - val_r2_score: -23.1848
# Epoch 28/30
# 81/81 [==============================] - 1s 10ms/step - loss: 9.7061e-05 - mean_squared_error: 1.9412e-04 - mean_absolute_error: 0.0092 - r2_score: 0.9775 - val_loss: 0.1324 - val_mean_squared_error: 0.2665 - val_mean_absolute_error: 0.4066 - val_r2_score: -15.1514
# Epoch 29/30
# 81/81 [==============================] - 1s 9ms/step - loss: 9.6651e-05 - mean_squared_error: 1.9330e-04 - mean_absolute_error: 0.0091 - r2_score: 0.9776 - val_loss: 0.1755 - val_mean_squared_error: 0.3563 - val_mean_absolute_error: 0.4640 - val_r2_score: -20.6509
# Epoch 30/30
# 81/81 [==============================] - 1s 9ms/step - loss: 8.9836e-05 - mean_squared_error: 1.7967e-04 - mean_absolute_error: 0.0090 - r2_score: 0.9792 - val_loss: 0.1944 - val_mean_squared_error: 0.3966 - val_mean_absolute_error: 0.5019 - val_r2_score: -23.0981
# d:\DELL\Desktop\COS30018\COS30018\ProjectAssessment\TaskB1\myenv\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# d:\DELL\Desktop\COS30018\COS30018\ProjectAssessment\TaskB1\myenv\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 2s 2s/step
